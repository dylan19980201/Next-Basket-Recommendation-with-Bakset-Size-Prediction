# %% [markdown]
# # 1. 載入套件

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm # 進度條
import os

from gensim.models import Word2Vec
import multiprocessing as mp
print("Number of CPU cores:", mp.cpu_count())
# Out:
# Number of CPU cores: 20

# %% [markdown]
# # 2.讀取資料

# %% [markdown]
# - TaFeng Dataset
# - Dunnhumby Dataset
# - Instacart Dataset

# %%
# dataset_name = "TaFeng"
# dataset_name = "Dunnhumby"
dataset_name = "Instacart"
df = pd.read_csv("../cleaned_dataset/" + dataset_name + "_clean.csv")
df
# Out:
#          CUSTOMER_ID  ORDER_NUMBER  PRODUCT_ID  CART_ID  NEW_ITEM_ID
# 0                  1             1         196        0            0
# 1                  1             1       14084        0            1
# 2                  1             1       12427        0            2
# 3                  1             1       26088        0            3
# 4                  1             1       26405        0            4
# ...              ...           ...         ...      ...          ...
# 3252971        20620             5       22963   295153           74
# 3252972        20620             5       12204   295153         1604
# 3252973        20620             5       21543   295153         3295
# 3252974        20620             5       23541   295153          417
# 3252975        20620             5       45106   295153         2494
#
# [3252976 rows x 5 columns]

# %% [markdown]
# # 3. Item2Vec方法
#
# ## 使用gensim 的 Word2Vec (將window sizes設為很大)
#
# https://github.com/ikatsov/tensor-house/blob/master/recommendations/item2vec.ipynb

# %%
# 建立一個cart_list(相當於句子)，其中每個 cart 還包含此購物車中所有item ID(相當於單詞) list。
def make_item_corpus(df_list):
    print("建立項目語料庫中...")
    item_list = []
    cart_list = []
    new_cart_id = df_list[0][0]
    for (CART_ID, ITEM_ID) in tqdm(df_list):
        if new_cart_id != CART_ID:
            cart_list.append(item_list)
            item_list = []
            new_cart_id = CART_ID
        item_list.append(ITEM_ID)
    cart_list.append
    print(cart_list[:10])
    return cart_list

# %%
def word2vec(cart_list, DATASET_NAME, TRAIN_ITEM_MODEL):
    # TRAIN_ITEM_MODEL: True - create a new model, False - Load a previously created model
    LOGGING_ENABLED = True
    MODEL_DIR = "../preprocessing-data/item2vec_models"
    
    if not os.path.exists(MODEL_DIR):
        os.makedirs(MODEL_DIR)
        
    if LOGGING_ENABLED:
        import logging
        logging.basicConfig(format="%(levelname)s - %(asctime)s : %(message)s", datefmt="%H:%M:%S", level=logging.INFO)
    
    # 設定嵌入維度
    WORD_DIM = 16
    model_filename = f"../preprocessing-data/item2vec_models/item2vec_{DATASET_NAME}.{WORD_DIM}d.model"
    if TRAIN_ITEM_MODEL:
        model = Word2Vec(sentences = cart_list, 
                         vector_size = WORD_DIM,
                         window = 500, 
                         sg = 1,
                         hs = 0, 
                         negative = 5,
                         ns_exponent = 0.75,
                         workers = 4,
                         min_count = 1)
        model.save(model_filename)
        print(f"Model saved to [{model_filename}]")
        
    else:
        model = Word2Vec.load(model_filename)
        print(f"Model loaded from[{model_filename}]")
    return model

# %% [markdown]
# **1.TaFeng Dataset\
# 2.Dunnhumby Dataset\
# 3.Instacart Dataset**

# %%
# 購物車, 新項目id, 串列
df_list = df[["CART_ID", "NEW_ITEM_ID"]].values.tolist()
df_list[:10]
# Out:
# [[0, 0],
#  [0, 1],
#  [0, 2],
#  [0, 3],
#  [0, 4],
#  [1, 0],
#  [1, 5],
#  [1, 2],
#  [1, 6],
#  [1, 3]]

# %%
cart_list = make_item_corpus(df_list)
model = word2vec(cart_list, dataset_name, True)
# Out:
# 建立項目語料庫中...
#   0%|          | 0/3252976 [00:00<?, ?it/s]
# INFO - 22:33:42 : collecting all words and their counts
# [[0, 1, 2, 3, 4], [0, 5, 2, 6, 3, 7], [0, 2, 5, 8, 9], [0, 2, 5, 8, 4], [0, 2, 5, 8, 10, 11, 12, 6], [0, 2, 5, 8], [0, 5, 2, 8, 7], [2, 0, 5, 8, 13, 14], [14, 13, 8, 0, 5, 2], [0, 13, 15, 16, 8, 5, 17, 7, 2]]
# INFO - 22:33:42 : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 22:33:42 : PROGRESS: at sentence #10000, processed 109482 words, keeping 12258 word types
# INFO - 22:33:42 : PROGRESS: at sentence #20000, processed 216112 words, keeping 16480 word types
# INFO - 22:33:42 : PROGRESS: at sentence #30000, processed 325883 words, keeping 18874 word types
# INFO - 22:33:43 : PROGRESS: at sentence #40000, processed 439103 words, keeping 20694 word types
# INFO - 22:33:43 : PROGRESS: at sentence #50000, processed 543593 words, keeping 21941 word types
# INFO - 22:33:43 : PROGRESS: at sentence #60000, processed 654215 words, keeping 22896 word types
# INFO - 22:33:43 : PROGRESS: at sentence #70000, processed 764399 words, keeping 23691 word types
# INFO - 22:33:43 : PROGRESS: at sentence #80000, processed 878877 words, keeping 24279 word types
# INFO - 22:33:43 : PROGRESS: at sentence #90000, processed 986768 words, keeping 24747 word types
# INFO - 22:33:43 : PROGRESS: at sentence #100000, processed 1093658 words, keeping 25134 word types
# INFO - 22:33:43 : PROGRESS: at sentence #110000, processed 1201649 words, keeping 25490 word types
# INFO - 22:33:43 : PROGRESS: at sentence #120000, processed 1307294 words, keeping 25749 word types
# INFO - 22:33:43 : PROGRESS: at sentence #130000, processed 1420030 words, keeping 25975 word types
# INFO - 22:33:43 : PROGRESS: at sentence #140000, processed 1529914 words, keeping 26167 word types
# INFO - 22:33:43 : PROGRESS: at sentence #150000, processed 1640790 words, keeping 26351 word types
# INFO - 22:33:43 : PROGRESS: at sentence #160000, processed 1750218 words, keeping 26500 word types
# INFO - 22:33:43 : PROGRESS: at sentence #170000, processed 1864916 words, keeping 26633 word types
# INFO - 22:33:43 : PROGRESS: at sentence #180000, processed 1978259 words, keeping 26735 word types
# INFO - 22:33:43 : PROGRESS: at sentence #190000, processed 2091831 words, keeping 26793 word types
# INFO - 22:33:43 : PROGRESS: at sentence #200000, processed 2201783 words, keeping 26859 word types
# INFO - 22:33:43 : PROGRESS: at sentence #210000, processed 2316232 words, keeping 26911 word types
# INFO - 22:33:43 : PROGRESS: at sentence #220000, processed 2428927 words, keeping 26949 word types
# INFO - 22:33:43 : PROGRESS: at sentence #230000, processed 2538699 words, keeping 26978 word types
# INFO - 22:33:43 : PROGRESS: at sentence #240000, processed 2650367 words, keeping 27002 word types
# INFO - 22:33:43 : PROGRESS: at sentence #250000, processed 2763369 words, keeping 27032 word types
# INFO - 22:33:43 : PROGRESS: at sentence #260000, processed 2874247 words, keeping 27060 word types
# INFO - 22:33:43 : PROGRESS: at sentence #270000, processed 2979873 words, keeping 27070 word types
# INFO - 22:33:43 : PROGRESS: at sentence #280000, processed 3086018 words, keeping 27082 word types
# INFO - 22:33:43 : PROGRESS: at sentence #290000, processed 3196997 words, keeping 27089 word types
# INFO - 22:33:43 : collected 27095 word types from a corpus of 3252957 raw words and 295153 sentences
# INFO - 22:33:43 : Creating a fresh vocabulary
# INFO - 22:33:43 : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 27095 unique words (100.00% of original 27095, drops 0)', 'datetime': '2024-03-25T22:33:43.355152', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# INFO - 22:33:43 : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 3252957 word corpus (100.00% of original 3252957, drops 0)', 'datetime': '2024-03-25T22:33:43.355152', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# INFO - 22:33:43 : deleting the raw counts dictionary of 27095 items
# INFO - 22:33:43 : sample=0.001 downsamples 18 most-common words
# INFO - 22:33:43 : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 3124079.1951788566 word corpus (96.0%% of prior 3252957)', 'datetime': '2024-03-25T22:33:43.418746', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# INFO - 22:33:43 : estimated required memory for 27095 words and 16 dimensions: 17015660 bytes
# INFO - 22:33:43 : resetting layer weights
# INFO - 22:33:43 : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-03-25T22:33:43.510746', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'build_vocab'}
# INFO - 22:33:43 : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 27095 vocabulary and 16 features, using sg=1 hs=0 sample=0.001 negative=5 window=500 shrink_windows=True', 'datetime': '2024-03-25T22:33:43.511746', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'train'}
# INFO - 22:33:44 : EPOCH 0 - PROGRESS: at 18.28% examples, 550075 words/s, in_qsize 8, out_qsize 0
# INFO - 22:33:45 : EPOCH 0 - PROGRESS: at 35.31% examples, 537189 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:46 : EPOCH 0 - PROGRESS: at 45.28% examples, 456027 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:47 : EPOCH 0 - PROGRESS: at 55.08% examples, 415618 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:48 : EPOCH 0 - PROGRESS: at 63.95% examples, 390222 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:49 : EPOCH 0 - PROGRESS: at 73.32% examples, 374036 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:50 : EPOCH 0 - PROGRESS: at 82.45% examples, 360989 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:51 : EPOCH 0 - PROGRESS: at 92.70% examples, 354588 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:52 : EPOCH 0: training on 3252957 raw words (3124011 effective words) took 8.9s, 351644 effective words/s
# INFO - 22:33:53 : EPOCH 1 - PROGRESS: at 8.98% examples, 267821 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:54 : EPOCH 1 - PROGRESS: at 18.94% examples, 286233 words/s, in_qsize 7, out_qsize 0
# INFO - 22:33:55 : EPOCH 1 - PROGRESS: at 28.34% examples, 289154 words/s, in_qsize 7, out_qsize 0
words/s, in_qsize 7, out_qsize 0
# INFO - 22:34:34 : EPOCH 4 - PROGRESS: at 95.26% examples, 290662 words/s, in_qsize 7, out_qsize 0
# INFO - 22:34:35 : EPOCH 4: training on 3252957 raw words (3124159 effective words) took 10.7s, 291131 effective words/s
# INFO - 22:34:35 : Word2Vec lifecycle event {'msg': 'training on 16264785 raw words (15620428 effective words) took 51.7s, 301978 effective words/s', 'datetime': '2024-03-25T22:34:35.238137', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'train'}
# INFO - 22:34:35 : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=27095, vector_size=16, alpha=0.025>', 'datetime': '2024-03-25T22:34:35.239137', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}
# INFO - 22:34:35 : Word2Vec lifecycle event {'fname_or_handle': '../preprocessing-data/item2vec_models/item2vec_Instacart.16d.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-03-25T22:34:35.239137', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'saving'}
# INFO - 22:34:35 : not storing attribute cum_table
# INFO - 22:34:35 : saved ../preprocessing-data/item2vec_models/item2vec_Instacart.16d.model
# Model saved to [../preprocessing-data/item2vec_models/item2vec_Instacart.16d.model]

# %%
# Prepare the embeddings
word_vectors = model.wv
vocab = list(model.wv.key_to_index.keys())
item2vector_dict = {arg:model.wv[arg] for arg in vocab}
X = pd.DataFrame(item2vector_dict).T.values
X.shape, len(vocab), vocab[0]
# Out:
# ((27095, 16), 27095, 44)

# %% [markdown]
# ## 檢查

# %%
model.wv.key_to_index
# Out:
# {44: 0,
#  6: 1,
#  149: 2,
#  141: 3,
#  45: 4,
#  20: 5,
#  402: 6,
#  29: 7,
#  31: 8,
#  266: 9,
#  18: 10,
#  501: 11,
#  1001: 12,
#  209: 13,
#  151: 14,
#  216: 15,
#  959: 16,
#  486: 17,
#  196: 18,
#  236: 19,
#  247: 20,
#  225: 21,
#  456: 22,
#  30: 23,
#  159: 24,
#  283: 25,
#  111: 26,
#  190: 27,
#  42: 28,
#  1275: 29,
#  308: 30,
#  28: 31,
#  184: 32,
#  14: 33,
#  362: 34,
#  273: 35,
#  521: 36,
#  396: 37,
#  182: 38,
#  679: 39,
#  185: 40,
#  1699: 41,
#  404: 42,
#  158: 43,
#  1610: 44,
#  110: 45,
#  544: 46,
#  17: 47,
#  410: 48,
#  636: 49,
#  257: 50,
#  163: 51,
#  1289: 52,
#  115: 53,
#  2914: 54,
#  1805: 55,
#  393: 56,
#  681: 57,
#  121: 58,
#  1538: 59,
#  206: 60,
#  84: 61,
#  2158: 62,
#  945: 63,
#  113: 64,
#  405: 65,
#  214: 66,
#  204: 67,
#  443: 68,
#  518: 69,
#  1827: 70,
#  2313: 71,
#  373: 72,
#  264: 73,
#  27: 74,
#  1562: 75,
#  202: 76,
#  290: 77,
#  520: 78,
#  1248: 79,
#  437: 80,
#  267: 81,
#  1601: 82,
#  698: 83,
#  3150: 84,
#  296: 85,
#  98: 86,
#  1674: 87,
#  1298: 88,
#  36: 89,
#  120: 90,
#  292: 91,
#  298: 92,
#  50: 93,
#  12: 94,
#  371: 95,
#  401: 96,
#  1771: 97,
#  515: 98,
#  364: 99,
#  242: 100,
#  147: 101,
#  2507: 102,
#  237: 103,
#  3484: 467,
#  708: 468,
#  2543: 469,
#  394: 470,
#  4838: 471,
#  1484: 472,
#  2348: 473,
#  470: 474,
#  248: 475,
#  2682: 476,
#  2659: 477,
#  672: 478,
#  1572: 479,
#  1454: 480,
#  2187: 481,
#  1231: 482,
#  3300: 483,
#  2141: 484,
#  2134: 485,
#  3093: 486,
#  3381: 487,
#  1407: 488,
#  682: 489,
#  5526: 490,
#  155: 491,
#  2164: 492,
#  1644: 493,
#  59: 494,
#  269: 495,
#  6542: 496,
#  883: 497,
#  1005: 498,
#  2255: 499,
#  2428: 500,
#  71: 501,
#  1722: 502,
#  699: 503,
#  1288: 504,
#  5218: 505,
#  2853: 506,
#  2293: 507,
#  51: 508,
#  2137: 509,
#  1806: 510,
#  1533: 511,
#  1078: 512,
#  1612: 513,
#  3223: 514,
#  919: 515,
#  2703: 516,
#  1613: 517,
#  67: 518,
#  5371: 519,
#  99: 520,
#  2674: 521,
#  1867: 522,
#  922: 523,
#  1312: 524,
#  72: 525,
#  478: 526,
#  408: 527,
#  3296: 528,
#  2271: 529,
#  2742: 530,
#  5509: 531,
#  282: 532,
#  1915: 533,
#  399: 534,
#  3405: 535,
#  1824: 536,
#  407: 537,
#  2089: 538,
#  2284: 539,
#  1826: 540,
#  993: 541,
#  333: 542,
#  265: 543,
#  988: 544,
#  1064: 545,
#  3968: 546,
#  2249: 547,
#  327: 548,
#  4706: 549,
#  2123: 550,
#  1643: 551,
#  2918: 552,
#  285: 553,
#  6002: 554,
#  863: 555,
#  3544: 556,
#  529: 557,
#  229: 558,
#  1608: 559,
#  2673: 560,
#  1683: 561,
#  2552: 562,
#  4084: 563,
#  2578: 564,
#  1421: 565,
#  2500: 566,
#  2289: 567,
#  1137: 568,
#  2078: 569,
#  1290: 570,
#  793: 571,
#  165: 572,
#  10370: 573,
#  2719: 574,
#  3666: 575,
#  1785: 576,
#  403: 577,
#  2890: 578,
#  995: 579,
#  2132: 580,
#  1558: 581,
#  3962: 582,
#  5798: 583,
#  1511: 584,
#  381: 585,
#  5783: 586,
#  3060: 587,
#  1702: 588,
#  1209: 589,
#  3294: 590,
#  2773: 591,
#  1812: 592,
#  2653: 593,
#  112: 594,
#  1783: 595,
#  496: 596,
#  1092: 597,
#  3435: 598,
#  1858: 599,
#  2654: 600,
#  2708: 601,
#  772: 602,
#  2067: 603,
#  143: 604,
#  701: 605,
#  1106: 606,
#  1682: 607,
#  1549: 608,
#  2251: 609,
#  1628: 610,
#  1940: 611,
#  1013: 612,
#  6403: 613,
#  5779: 614,
#  3073: 615,
#  400: 616,
#  3289: 617,
#  1737: 618,
#  5129: 619,
#  4667: 620,
#  2257: 621,
#  3360: 622,
#  466: 623,
#  1250: 624,
#  6501: 625,
#  1180: 626,
#  2819: 627,
#  4344: 628,
#  10852: 629,
#  3295: 630,
#  3013: 631,
#  3832: 632,
#  3830: 633,
#  3521: 634,
#  323: 635,
#  1832: 636,
#  3152: 637,
#  3080: 638,
#  314: 639,
#  33: 640,
#  3128: 641,
#  88: 642,
#  1135: 643,
#  2646: 644,
#  3311: 645,
#  3113: 646,
#  6224: 647,
#  3900: 648,
#  2270: 649,
#  1870: 650,
#  3292: 651,
#  2219: 652,
#  1605: 653,
#  3437: 654,
#  458: 655,
#  425: 656,
#  3146: 657,
#  489: 658,
#  3721: 659,
#  5769: 660,
#  2028: 661,
#  2359: 662,
#  2748: 663,
#  511: 664,
#  2421: 665,
#  1073: 666,
#  4370: 667,
#  3301: 668,
#  1446: 669,
#  1400: 670,
#  8819: 671,
#  1295: 672,
#  3173: 673,
#  1839: 674,
#  2345: 675,
#  1791: 676,
#  1114: 677,
#  1685: 678,
#  1540: 679,
#  433: 680,
#  1868: 681,
#  1758: 682,
#  1673: 683,
#  87: 684,
#  2702: 685,
#  194: 686,
#  2667: 687,
#  2405: 688,
#  2349: 689,
#  5750: 690,
#  2157: 691,
#  356: 692,
#  70: 693,
#  4088: 694,
#  2037: 695,
#  1636: 696,
#  8796: 697,
#  35: 698,
#  271: 699,
#  3058: 700,
#  1217: 701,
#  2433: 702,
#  384: 703,
#  1744: 704,
#  52: 705,
#  3655: 706,
#  6243: 707,
#  167: 708,
#  2102: 709,
#  342: 710,
#  818: 711,
#  436: 712,
#  4590: 713,
#  3133: 714,
#  1861: 715,
#  3845: 716,
#  1697: 717,
#  4591: 718,
#  1742: 719,
#  5276: 720,
#  5888: 721,
#  2110: 722,
#  3151: 723,
#  1789: 724,
#  949: 725,
#  188: 726,
#  3345: 727,
#  1574: 728,
#  3348: 729,
#  420: 730,
#  3839: 731,
#  1954: 732,
#  2047: 733,
#  295: 734,
#  2701: 735,
#  256: 736,
#  142: 737,
#  1761: 738,
#  3246: 739,
#  2422: 740,
#  1763: 741,
#  2727: 742,
#  4563: 743,
#  4837: 744,
#  2856: 745,
#  1844: 746,
#  338: 747,
#  2328: 748,
#  4094: 749,
#  3022: 750,
#  1166: 751,
#  4930: 752,
#  1470: 753,
#  25: 754,
#  1802: 755,
#  3083: 756,
#  5027: 757,
#  4553: 758,
#  671: 759,
#  8902: 760,
#  927: 761,
#  5780: 762,
#  1481: 763,
#  310: 764,
#  923: 765,
#  2086: 766,
#  632: 767,
#  1820: 768,
#  6676: 769,
#  2999: 770,
#  2695: 771,
#  4407: 772,
#  8457: 773,
#  3125: 774,
#  4402: 775,
#  1240: 776,
#  1815: 777,
#  933: 778,
#  2383: 779,
#  8869: 780,
#  5076: 781,
#  1556: 782,
#  2621: 783,
#  1104: 784,
#  1598: 785,
#  535: 786,
#  3615: 787,
#  1985: 788,
#  1297: 789,
#  3090: 790,
#  3481: 791,
#  2912: 792,
#  1874: 793,
#  5293: 794,
#  32: 795,
#  1276: 796,
#  6394: 797,
#  3009: 798,
#  1866: 799,
#  8188: 800,
#  1700: 801,
#  4076: 802,
#  2891: 803,
#  13: 804,
#  261: 805,
#  2736: 806,
#  164: 807,
#  493: 808,
#  5574: 809,
#  2997: 810,
#  1890: 811,
#  1079: 812,
#  6922: 813,
#  6130: 814,
#  2651: 815,
#  683: 816,
#  3698: 817,
#  2932: 818,
#  6924: 819,
#  2940: 820,
#  4732: 821,
#  5137: 822,
#  1399: 823,
#  695: 824,
#  2722: 825,
#  4487: 826,
#  1864: 827,
#  9156: 828,
#  1555: 829,
#  1272: 830,
#  3649: 831,
#  3249: 832,
#  2609: 833,
#  300: 834,
#  5701: 835,
#  1284: 836,
#  53: 837,
#  4685: 838,
#  2694: 839,
#  1706: 840,
#  3035: 841,
#  245: 842,
#  5512: 843,
#  12088: 844,
#  3096: 845,
#  1294: 846,
#  3027: 847,
#  4700: 848,
#  1119: 849,
#  804: 850,
#  4537: 851,
#  348: 852,
#  1285: 853,
#  224: 854,
#  152: 855,
#  6696: 856,
#  10475: 857,
#  4107: 858,
#  4720: 859,
#  540: 860,
#  7432: 861,
#  1281: 862,
#  5561: 863,
#  5330: 864,
#  3078: 865,
#  503: 866,
#  3670: 867,
#  3784: 868,
#  446: 869,
#  513: 870,
#  2480: 871,
#  2010: 872,
#  2789: 873,
#  2283: 874,
#  5219: 875,
#  2607: 876,
#  4747: 877,
#  573: 878,
#  1865: 879,
#  2658: 880,
#  4489: 881,
#  1162: 882,
#  1130: 883,
#  7475: 884,
#  5304: 885,
#  2231: 886,
#  2830: 887,
#  353: 888,
#  1757: 889,
#  554: 890,
#  146: 891,
#  3884: 892,
#  8: 893,
#  979: 894,
#  1924: 895,
#  5893: 896,
#  7114: 897,
#  459: 898,
#  1764: 899,
#  157: 900,
#  291: 901,
#  1642: 902,
#  5232: 903,
#  4879: 904,
#  1343: 905,
#  6106: 906,
#  1523: 907,
#  1721: 908,
#  3141: 909,
#  7611: 910,
#  954: 911,
#  2729: 912,
#  378: 913,
#  2208: 914,
#  1716: 915,
#  8926: 916,
#  2636: 917,
#  4373: 918,
#  2403: 919,
#  940: 920,
#  6072: 921,
#  8402: 922,
#  2613: 923,
#  668: 924,
#  3838: 925,
#  8204: 926,
#  241: 927,
#  451: 928,
#  131: 929,
#  3916: 930,
#  3385: 931,
#  1944: 932,
#  915: 933,
#  3120: 934,
#  2162: 935,
#  4082: 936,
#  4383: 937,
#  2852: 938,
#  1664: 939,
#  370: 940,
#  3119: 941,
#  235: 942,
#  3697: 943,
#  2724: 944,
#  4798: 945,
#  2494: 946,
#  365: 947,
#  3738: 948,
#  4289: 949,
#  5146: 950,
#  132: 951,
#  3551: 952,
#  2286: 953,
#  61: 954,
#  1849: 955,
#  4327: 956,
#  1749: 957,
#  5855: 958,
#  1955: 959,
#  3892: 960,
#  2052: 961,
#  823: 962,
#  8330: 963,
#  4554: 964,
#  1246: 965,
#  7501: 966,
#  4551: 967,
#  1177: 968,
#  5654: 969,
#  2432: 970,
#  3840: 971,
#  6211: 972,
#  2415: 973,
#  3061: 974,
#  1546: 975,
#  1992: 976,
#  5064: 977,
#  461: 978,
#  691: 979,
#  10939: 980,
#  4847: 981,
#  2898: 982,
#  653: 983,
#  1201: 984,
#  4920: 985,
#  5937: 986,
#  11092: 987,
#  875: 988,
#  8923: 989,
#  5600: 990,
#  4467: 991,
#  8131: 992,
#  7469: 993,
#  60: 994,
#  764: 995,
#  5155: 996,
#  3265: 997,
#  3226: 998,
#  344: 999,
#  ...}
